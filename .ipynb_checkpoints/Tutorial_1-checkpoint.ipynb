# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1,20,7)

# %%
def fx(x):
    return 2*x*np.sin(0.8*x)

# %%
plt.plot(x,fx(x))

# %%
def linear_interpolation(x, num_values, begin, end):
    y = fx(x)
    # interpolated y values
    y_values = np.linspace(begin,end,num_values)
    # interpolated x values
    x_values = np.linspace(begin,end,num_values)
    # values of the slope between points
    a_values = []
    
    # Interpolation
    for i in range(len(x)-1):
        # compute the slope between current and next point
        a = ( y[i+1] - y[i] ) / (x[i+1] - x[i])
        a_values.append(a)
    
    for 
        
    # Extrapolation
#     a = ( y[i+1] - y[i] ) / (x[i+1] - x[i])
#     xnow = x_values[(x_values > x[i+1])]
#     y_values.append( a*(x[i]-xnow) + y[i])

    i = 3
    # compute the slope between current and next point
    a = ( y[i+1] - y[i] ) / (x[i+1] - x[i])
    # Find all x between current and next point
    xnow = x_values[(x_values < x[i+1]) & (x_values >= x[i])]

    # y = y0 + a*delta_x
    y_values = (a*(x[i]-xnow[0]) + y[i])
    
    return x_values, np.asarray(y_values).flatten()

# %%
x_values, y_values = linear_interpolation(x, 100, 1, 25)
print (len(x_values),len(y_values))
# Out:
# 100 1

# %%
plt.scatter(x_values[40],y_values[0],label='linear interp')
plt.plot(x,fx(x))
plt.legend()
